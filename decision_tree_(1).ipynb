# %% [markdown]
# <a href="https://colab.research.google.com/github/e42240950-RafifDwiPradipta/Sistem-cerdas-movies-knn-kelompok-pakdhe/blob/main/decision_tree_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('/decisiontree_1.csv')
encoding = {"mesin": {"bensin": 0, "diesel": 1},
            "penggerak": {"depan": 0, "belakang": 1}}
data.replace(encoding, inplace=True)
# Out:
# /tmp/ipython-input-1323165165.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace(encoding, inplace=True)

# %%
data.head()
# Out:
#    ID  mesin  bangku  penggerak    label
# 0   1      0       4          0    sedan
# 1   2      0       2          0    sedan
# 2   3      0       8          1  minibus
# 3   4      1       6          0  minibus
# 4   5      0       5          1  minibus

# %%
x = data.drop(['ID', 'label'], axis =1)
y = data['label']

# %%
import sklearn.model_selection as ms
x_train, x_test, y_train, y_test = ms.train_test_split(x, y, test_size=0.4)

# %%
import sklearn.tree as tree
model = tree.DecisionTreeClassifier(criterion='gini', max_depth=5)
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
y_pediksi = model.predict(x_test)
y_pediksi
# Out:
# array(['sedan', 'sedan', 'sedan', 'sedan', 'sedan', 'minibus', 'minibus',
#        'minibus', 'sedan', 'sedan', 'sedan', 'sedan', 'minibus', 'sedan'],
#       dtype=object)

# %%
import sklearn.metrics as met
print(met.accuracy_score(y_test, y_pediksi))
# Out:
# 0.9285714285714286

# %%
import matplotlib.pyplot as plt
from sklearn import tree

plt.figure(figsize=(10, 10))  # Gunakan figure, bukan subplot
tree.plot_tree(model, fontsize=10)
plt.show()
